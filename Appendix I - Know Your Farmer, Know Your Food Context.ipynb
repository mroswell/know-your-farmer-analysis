# %% [markdown]
# ## Links Extracted from the "Know Your Farmer" PDF
#
# This USDA document gives a beautiful overview of the Know Your Farmer, Know Your Food program.
# https://www.usda.gov/sites/default/files/documents/KYFCompass.pdf
#
# This pdf_links.py extractor at https://github.com/moshekaplan/pdf_analysis_tools has a tool to extract links, offering  helpful context. (Many are 404 links i.e. "Page Not Found" links). Many of these missing pages can still be viewed (if you want to try) on archive.org.)

# %%
import pandas as pd

# %%
! python pdf_links.py KYFCompass.pdf > kyf_link_list.csv
kyf_link_df = pd.read_csv('list.csv', skiprows=1, header=None)
kyf_link_list = pd.Series(kyf_link_df[0]).tolist()
for url in kyf_link_list:
    print url
# Out:
# http://blogs.usda.gov/2010/03/12/a-tour-of-how-forest-service-job-corps-program-changes-lives/
# http://blogs.usda.gov/2010/07/29/high-tunnels-a-three-year-pilot-practice/
# http://blogs.usda.gov/2010/08/07/usda-and-sba-team-up-for-small-rural-business-in-iowa/
# http://blogs.usda.gov/2010/08/23/mapping-slaughter-availability-in-u-s/
# http://blogs.usda.gov/2010/08/27/just-what-the-doctor-ordered/
# http://blogs.usda.gov/2010/08/30/an-introduction-to-mobile-slaughter-units/
# http://blogs.usda.gov/2010/09/01/farmers-markets-as-small-business-incubators/
# http://blogs.usda.gov/2010/09/16/agroforestry-means-food-prosperity%E2%80%A6-and-more/
# http://blogs.usda.gov/2010/09/23/know-your-sooner-know-your-food/
# http://blogs.usda.gov/2010/09/27/earn-your-healthy-eating-badge-and-check-in-with-the-usda%e2%80%99s-national-farmers-market-directory/
# http://blogs.usda.gov/2010/11/15/connecting-children-to-food-and-farming-agriculture-in-the-classroom/
# ...
